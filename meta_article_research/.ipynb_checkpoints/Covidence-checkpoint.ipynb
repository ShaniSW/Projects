# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the data from the Excel file
num_rows_to_read = 553

covidence = pd.read_excel('Copy of Survey-covidence all - in work 2.xlsx', sheet_name='All - covidence', nrows=num_rows_to_read)
print(covidence.columns)
# Out:
# Index(['Title', 'Authors', 'Published Year', 'Published Month', 'Journal',
#        'Volume', 'Issue', 'Pages', 'Accession Number', 'DOI', 'Ref',
#        'Covidence #', 'Study', 'Abstract', 'reject', 'Author keywords',
#        'Neuro', 'Unnamed: 17', 'Unnamed: 18', 'N', 'age', 'Maths',
#        'Unnamed: 22', 'Unnamed: 23', 'Psychology', 'Unnamed: 25',
#        'Unnamed: 26', 'notes'],
#       dtype='object')

# %%
print(covidence[covidence['Published Year'].isna()])
# Out:
# Empty DataFrame
# Columns: [Title, Authors, Published Year, Published Month, Journal, Volume, Issue, Pages, Accession Number, DOI, Ref, Covidence #, Study, Abstract, reject, Author keywords, Neuro, Unnamed: 17, Unnamed: 18, N, age, Maths, Unnamed: 22, Unnamed: 23, Psychology, Unnamed: 25, Unnamed: 26, notes]
# Index: []
#
# [0 rows x 28 columns]

# %%
covidence['Published Year'] = covidence['Published Year'].astype(int).astype(str)
covidence['Published Date'] = covidence['Published Year'].astype(str) + '/' + covidence['Published Month'].astype(str)
print(covidence['Published Date'])
# Out:
# 0      2023/01/28/
# 1      2013/04/17/
# 2      2007/05/01/
# 3      2020/04/15/
# 4        2004/02//
#           ...
# 548      2014/06//
# 549    2020/01/01/
# 550    2012/12/01/
# 551    2013/01/02/
# 552    2018/04/24/
# Name: Published Date, Length: 553, dtype: object

# %% [markdown]
# # 1. Number of Articles Published per Year

# %%
# Assuming 'covidence' is your DataFrame
# Assuming 'Published Year' is the column containing the publication years

# Calculate the number of articles published per year
articles_per_year = covidence['Published Year'].value_counts()

print(articles_per_year)

# Sort the series by index (year)
articles_per_year_sorted = articles_per_year.sort_index()

# Plot the data
plt.figure(figsize=(10, 6))
articles_per_year_sorted.plot(kind='bar', color='skyblue')
plt.title('Number of Articles Published per Year')
plt.xlabel('Year')
plt.ylabel('Number of Articles')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Published Year
# 2019    48
# 2020    46
# 2023    45
# 2021    44
# 2018    42
# 2014    36
# 2022    35
# 2015    31
# 2016    28
# 2013    26
# 2017    25
# 2012    24
# 2011    23
# 2010    23
# 2009    18
# 2004     7
# 2008     7
# 2007     7
# 2006     7
# 2005     6
# 2024     6
# 2003     2
# 1995     2
# 2001     2
# 2002     2
# 1991     2
# 1996     2
# 1990     2
# 1992     1
# 1986     1
# 1987     1
# 1980     1
# 2000     1
# Name: count, dtype: int64

# %% [markdown]
# # 2. Number of Articles Dealing with methodology

# %%
# Define the search terms
search_terms = ['EEG', 'fMRI', 'eye-tracking', 'fNIRS', 'GSR', 'MEG']

# Convert the 'Author keywords' column to lowercase and fill NaN values with an empty string
s = covidence['Author keywords'].str.lower()

# Initialize a dictionary to store counts for each search term
term_counts = {term: 0 for term in search_terms}

# Loop through each term and count its occurrences in the 'Author keywords' column
for term in search_terms:
    if term == 'fMRI':
        count = s.str.contains('fmri|mri').sum()
    if term == 'EEG':
        count = s.str.contains('eeg|erp|erd').sum()
    else:
        count = s.str.contains(term.lower()).sum()
    print(f"{term}: {count}")
    term_counts[term] = count
    
# Plot the data
plt.figure(figsize=(10, 6))
plt.bar(term_counts.keys(), term_counts.values(), color='skyblue')
plt.title('Number of Articles Dealing with methodology')
plt.xlabel('Neuro')
plt.ylabel('Number of Articles')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# EEG: 150
# fMRI: 201
# eye-tracking: 153
# fNIRS: 30
# GSR: 2
# MEG: 4

# %% [markdown]
# # 3. Distribution of publications from 1980 to 2024 for each methodology

# %%
# Define the search terms
search_terms = ['EEG', 'fMRI', 'eye-tracking', 'fNIRS', 'GSR', 'MEG']

# Convert 'Author keywords' column to lowercase and replace 'mri' with 'fmri' for uniformity
covidence['Author keywords'] = covidence['Author keywords'].str.lower().str.replace('mri', 'fmri')
covidence['Author keywords'] = covidence['Author keywords'].str.lower().str.replace('eeg|erp|erd', 'eeg', regex=True)
# Initialize an empty dictionary to store counts for each term per year
term_counts_per_year = {
    term: covidence[covidence['Author keywords'].str.contains(term.lower())]['Published Year'].value_counts().sort_index() 
    for term in search_terms
}

# Ensure all years are included in the plots
years = sorted(set().union(*[counts.index for counts in term_counts_per_year.values()]))

# Plot the data
plt.figure(figsize=(12, 8))
for term, counts in term_counts_per_year.items():
    counts = counts.reindex(years, fill_value=0)  # Ensure counts for all years, fill missing with 0
    plt.bar(counts.index, counts.values, label=term)

plt.title('Distribution of publications from 1980 to 2024 for each methodology')
plt.xlabel('Year')
plt.ylabel('Number of Articles')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Display number of articles per search term and year in a table
article_counts = pd.DataFrame(index=years)

for term in search_terms:
    term_counts_per_year = covidence[covidence['Author keywords'].str.contains(term.lower())]['Published Year'].value_counts().sort_index()
    term_counts_per_year = term_counts_per_year.reindex(years, fill_value=0)  # Ensure counts for all years, fill missing with 0
    article_counts[term] = term_counts_per_year

print("\nNumber of Articles per Search Term and Year:\n", article_counts)
# Out:
# Number of Articles per Search Term and Year:
#        EEG  fMRI  eye-tracking  fNIRS  GSR  MEG
# 1980    0     0             1      0    0    0
# 1986    0     0             1      0    0    0
# 1987    1     0             0      0    0    0
# 1990    1     0             1      0    0    0
# 1991    1     0             1      0    0    0
# 1992    0     0             1      0    0    0
# 1995    1     0             1      0    0    0
# 1996    1     0             1      0    0    0
# 2000    0     1             0      0    0    0
# 2001    0     2             0      0    0    0
# 2002    0     2             0      0    0    0
# 2003    1     1             0      0    0    0
# 2004    2     5             0      0    0    0
# 2005    2     4             0      0    0    0
# 2006    1     6             0      0    0    0
# 2007    2     3             1      0    0    0
# 2008    1     4             1      1    0    1
# 2009    4    11             3      0    0    0
# 2010    6    16             0      1    0    0
# 2011    6    14             2      0    0    0
# 2012    5    13             2      1    0    0
# 2013   10     8             4      1    0    0
# 2014    8    12            13      1    0    1
# 2015   12     9             9      1    0    0
# 2016    7     8            10      2    0    0
# 2017    8     9             5      1    0    2
# 2018   16    15             9      4    0    0
# 2019   12    14            22      1    0    0
# 2020    9    13            19      4    1    0
# 2021   16    13             9      3    0    0
# 2022    6    17             8      5    0    0
# 2023    9     6            26      4    1    0
# 2024    2     1             3      0    0    0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the search terms
search_terms = ['EEG', 'fMRI', 'eye-tracking', 'fNIRS', 'MEG', 'GSR']

# Convert 'Author keywords' column to lowercase and replace 'mri' with 'fmri' for uniformity
covidence['Author keywords'] = covidence['Author keywords'].str.lower().str.replace('mri', 'fmri')
covidence['Author keywords'] = covidence['Author keywords'].str.lower().str.replace('eeg|erp|erd', 'eeg', regex=True)

def predicate(term, range):
    year_start, year_end = range
    numeric_year = pd.to_numeric(covidence['Published Year'])
    contains_term = covidence['Author keywords'].str.contains(term.lower())
    year_range = numeric_year.between(year_start, year_end)
    return contains_term & year_range

year_ranges = [
    (1980, 2010),
    (2011, 2025)
]

for year_range in year_ranges:
    # Initialize an empty dictionary to store counts for each term per year
    term_counts_per_year = {}
    for term in search_terms:
        relevant_rows = covidence[predicate(term, year_range)]
        published_year_column = relevant_rows['Published Year']
        term_counts_per_year[term] = published_year_column.value_counts().sort_index()
    
    # Ensure all years are included in the plots
    years = sorted(set().union(*[counts.index for counts in term_counts_per_year.values()]))
    
    # Plot the data
    plt.figure(figsize=(12, 8))
    width = 0.15  # Width of each bar
    
    # Positions of the bars on the x-axis
    positions = {term: [i + idx * width for i in range(len(years))] for idx, term in enumerate(search_terms)}
    
    for term, counts in term_counts_per_year.items():
        counts = counts.reindex(years, fill_value=0)  # Ensure counts for all years, fill missing with 0
        plt.bar(positions[term], counts.values, width=width, label=term)
    
    # Adjust x-ticks to be in the center of grouped bars
    plt.xticks([i + width*(len(search_terms)-1)/2 for i in range(len(years))], years, rotation=45)
    
    plt.title(f'Distribution of publications from {year_range[0]} to {year_range[1]} for each methodology')
    plt.xlabel('Year')
    plt.ylabel('Number of Articles')
    plt.legend()
    plt.grid(axis='y')
    plt.tight_layout()
    plt.ylim(0, 30)
    plt.show()
    
    # Display number of articles per search term and year in a table
    article_counts = pd.DataFrame(index=years)
    
    for term in search_terms:
        term_counts_per_year = covidence[covidence['Author keywords'].str.contains(term.lower())]['Published Year'].value_counts().sort_index()
        term_counts_per_year = term_counts_per_year.reindex(years, fill_value=0)  # Ensure counts for all years, fill missing with 0
        article_counts[term] = term_counts_per_year
    
    print("\nNumber of Articles per Search Term and Year:\n", article_counts)
# Out:
# Number of Articles per Search Term and Year:
#        EEG  fMRI  eye-tracking  fNIRS  MEG  GSR
# 1980    0     0             1      0    0    0
# 1986    0     0             1      0    0    0
# 1987    1     0             0      0    0    0
# 1990    1     0             1      0    0    0
# 1991    1     0             1      0    0    0
# 1992    0     0             1      0    0    0
# 1995    1     0             1      0    0    0
# 1996    1     0             1      0    0    0
# 2000    0     1             0      0    0    0
# 2001    0     2             0      0    0    0
# 2002    0     2             0      0    0    0
# 2003    1     1             0      0    0    0
# 2004    2     5             0      0    0    0
# 2005    2     4             0      0    0    0
# 2006    1     6             0      0    0    0
# 2007    2     3             1      0    0    0
# 2008    1     4             1      1    1    0
# 2009    4    11             3      0    0    0
# 2010    6    16             0      1    0    0
# Number of Articles per Search Term and Year:
#        EEG  fMRI  eye-tracking  fNIRS  MEG  GSR
# 2011    6    14             2      0    0    0
# 2012    5    13             2      1    0    0
# 2013   10     8             4      1    0    0
# 2014    8    12            13      1    1    0
# 2015   12     9             9      1    0    0
# 2016    7     8            10      2    0    0
# 2017    8     9             5      1    2    0
# 2018   16    15             9      4    0    0
# 2019   12    14            22      1    0    0
# 2020    9    13            19      4    0    1
# 2021   16    13             9      3    0    0
# 2022    6    17             8      5    0    0
# 2023    9     6            26      4    0    1
# 2024    2     1             3      0    0    0

# %% [markdown]
# # 4. Distribution of publications from 1980 to 2024 for each mathematical topics

# %%
# Assuming 'covidence' is your DataFrame
# Define the terms to search for
search_terms = ['Algebra', 'Geometry', 'Arithmetic', 'Numeracy', 'statistics', 'Calculus']

# Convert 'Author keywords' column to lowercase and replace 'mri' with 'fmri' for uniformity
covidence['Author keywords'] = covidence['Author keywords'].str.lower().str.replace('probability', 'statistics')

def predicate(term, range):
    year_start, year_end = range
    numeric_year = pd.to_numeric(covidence['Published Year'])
    contains_term = covidence['Author keywords'].str.contains(term.lower())
    year_range = numeric_year.between(year_start, year_end)
    return contains_term & year_range

year_ranges = [
    (1980, 2010),
    (2011, 2024)
]

for year_range in year_ranges:
    # Initialize an empty dictionary to store counts for each term per year
    term_counts_per_year = {}
    for term in search_terms:
        relevant_rows = covidence[predicate(term, year_range)]
        published_year_column = relevant_rows['Published Year']
        term_counts_per_year[term] = published_year_column.value_counts().sort_index()
    
    # Ensure all years are included in the plots
    years = sorted(set().union(*[counts.index for counts in term_counts_per_year.values()]))
    
    # Plot the data
    plt.figure(figsize=(12, 8))
    width = 0.15  # Width of each bar
    
    # Positions of the bars on the x-axis
    positions = {term: [i + idx * width for i in range(len(years))] for idx, term in enumerate(search_terms)}
    
    for term, counts in term_counts_per_year.items():
        counts = counts.reindex(years, fill_value=0)  # Ensure counts for all years, fill missing with 0
        plt.bar(positions[term], counts.values, width=width, label=term)
    
    # Adjust x-ticks to be in the center of grouped bars
    plt.xticks([i + width*(len(search_terms)-1)/2 for i in range(len(years))], years, rotation=45)
    
    plt.title(f'Distribution of publications from {year_range[0]} to {year_range[1]} for each mathematical topic')
    plt.xlabel('Year')
    plt.ylabel('Number of Articles')
    plt.legend()
    plt.grid(axis='y')
    plt.tight_layout()
    plt.ylim(0, 30)
    plt.show()
    
    # Display number of articles per search term and year in a table
    article_counts = pd.DataFrame(index=years)
    
    for term in search_terms:
        term_counts_per_year = covidence[covidence['Author keywords'].str.contains(term.lower())]['Published Year'].value_counts().sort_index()
        term_counts_per_year = term_counts_per_year.reindex(years, fill_value=0)  # Ensure counts for all years, fill missing with 0
        article_counts[term] = term_counts_per_year
    
    print("\nNumber of Articles per Search Term and Year:\n", article_counts)
# Out:
# Number of Articles per Search Term and Year:
#        Algebra  Geometry  Arithmetic  Numeracy  statistics  Calculus
# 1980        0         0           1         0           0         0
# 1986        0         0           1         0           0         0
# 1987        0         0           1         0           0         0
# 1990        0         0           1         1           0         0
# 1992        0         0           1         0           0         0
# 1995        0         0           2         1           0         0
# 1996        0         0           0         2           0         0
# 2000        0         0           1         1           0         0
# 2001        0         0           2         0           0         0
# 2002        0         0           2         1           0         0
# 2003        1         0           0         1           0         0
# 2004        4         0           2         2           0         0
# 2005        0         0           4         4           0         0
# 2006        0         0           2         4           0         0
# 2007        2         0           1         4           0         0
# 2008        3         0           1         2           0         1
# 2009        0         0          12         8           0         0
# 2010        4         2           9         5           0         0
# Number of Articles per Search Term and Year:
#        Algebra  Geometry  Arithmetic  Numeracy  statistics  Calculus
# 2011        4         0          11         6           0         0
# 2012        4         1          15         5           0         1
# 2013        2         1          14        10           0         0
# 2014        4         3          20         7           0         0
# 2015        0         1          24         6           0         0
# 2016        0         4          15         8           0         0
# 2017        2         1          12         4           1         1
# 2018        2         6          15         6           1         1
# 2019        8         4          20         5           0         1
# 2020        6         5          19        13           3         0
# 2021        1         3          24        10           0         0
# 2022        4         4          20         5           0         0
# 2023        6         8          16        10           2         1
# 2024        0         4           1         0           1         0

# %% [markdown]
# # 5. Frequency of mathematical topics for each methodology

# %%
# Define the search terms
search_terms = ['EEG', 'fMRI', 'eye-tracking', 'fNIRS', 'GSR', 'MEG']

# Convert the 'Author keywords' column to lowercase and fill NaN values with an empty string
s = covidence['Author keywords'].str.lower()

# Initialize a dictionary to store counts for each search term
term_counts = {term: 0 for term in search_terms}

# Loop through each term and count its occurrences in the 'Author keywords' column
for term in search_terms:
    if term == 'fMRI':
        count = s.str.contains('fmri|mri').sum()
    if term == 'EEG':
        count = s.str.contains('eeg|erp|erd').sum()
    else:
        count = s.str.contains(term.lower()).sum()
    print(f"{term}: {count}")
    term_counts[term] = count
    
# Plot the data
plt.figure(figsize=(10, 6))
plt.bar(term_counts.keys(), term_counts.values(), color='skyblue')
plt.title('Number of Articles Dealing with methodology')
plt.xlabel('Neuro')
plt.ylabel('Number of Articles')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 6. Authors with more than 5 articles

# %%
# Assuming 'covidence' is your DataFrame and it has an 'Authors' column
# Ensure the 'Authors' column is converted to strings
covidence['Authors'] = covidence['Authors'].astype(str).str.split(';')

# Count the occurrences of each author
author_counts = covidence['Authors'].explode().value_counts().sort_values(ascending=True)

# Filter authors with more than 5 articles
authors_more_than_5 = author_counts[author_counts > 5]

# Plot the data as a horizontal bar plot
authors_more_than_5.plot(kind='barh', color='skyblue', figsize=(10, 12))
plt.title('Authors with More Than 5 Articles')
plt.xlabel('Number of Articles')
plt.ylabel('Author')
plt.xticks(np.arange(0, max(author_counts)+1, 2))
plt.yticks(rotation=45, ha='right')  # Rotate author names by 45 degrees for better readability
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 7. Journals with more than 10 articles

# %%
# Assuming 'covidence' is your DataFrame
# Count the number of articles published in each journal
articles_per_journal = covidence['Journal'].str.lower().value_counts()

# Filter out journals with only one article
filtered_articles_per_journal = articles_per_journal[articles_per_journal > 1]

# Select the top 50 journals
top_10_journals = filtered_articles_per_journal.head(10)

# Print the filtered counts for each journal
print(top_10_journals)

# Plot the data as a horizontal bar plot
plt.figure(figsize=(12, 10))  # Adjust the figure size
top_10_journals.plot(kind='barh', color='skyblue')
plt.title('Number of Articles per Journal', fontsize=16)
plt.xlabel('Number of Articles', fontsize=14)
plt.ylabel('Journal', fontsize=14)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Journal
# neuroimage                           29
# neuropsychologia                     28
# developmental science                14
# frontiers in psychology              14
# journal of cognitive neuroscience    14
# frontiers in human neuroscience      14
# zdm - mathematics education          12
# plos one                             11
# human brain mapping                  10
# scientific reports                   10
# Name: count, dtype: int64

# %%
# Assuming 'covidence' is your DataFrame and it has a 'Journal' column
# Ensure the 'Journal' column is converted to strings
covidence['Journal'] = covidence['Journal'].astype(str).str.split(';')

# Count the occurrences of each journal
Journal_counts = covidence['Journal'].explode().value_counts()

# Filter journals with more than 10 articles
Journal_more_than_10 = Journal_counts[Journal_counts > 10]

# Plot the data as a horizontal bar plot
Journal_more_than_10.plot(kind='barh', color='skyblue', figsize=(10, 12))
plt.title('Journal with More Than 10 Articles')
plt.xlabel('Number of Articles')
plt.ylabel('Journal')
plt.yticks(rotation=45, ha='right')  # Rotate journal names by 45 degrees for better readability
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 8. Distribution of publications from 1980 to 2024 for each psychology topics

# %%
# Assuming 'covidence' is your DataFrame
# Define the terms to search for
search_terms = ['math anxiety', 'giftedness', 'excellence', 'disabilities', 'dyscalculia']

# Convert 'Author keywords' column to lowercase and replace 'mri' with 'fmri' for uniformity
covidence['Author keywords'] = covidence['Author keywords'].str.lower()

# Initialize an empty dictionary to store counts for each term per year
term_counts_per_year = {term: covidence[covidence['Author keywords'].str.contains(term.lower())]['Published Year'].value_counts().sort_index() for term in search_terms}

# Ensure all years are included in the plots
years = sorted(set().union(*[counts.index for counts in term_counts_per_year.values()]))

# Plot the data
plt.figure(figsize=(12, 8))
for term, counts in term_counts_per_year.items():
    counts = counts.reindex(years, fill_value=0)  # Ensure counts for all years, fill missing with 0
    plt.plot(counts.index, counts.values, marker='o', label=term)

plt.title('Distribution of publications from 1980 to 2024 for each psychology topics')
plt.xlabel('Year')
plt.ylabel('Number of Articles')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Display number of articles per search term and year in a table
article_counts = pd.DataFrame(index=years)

for term in search_terms:
    term_counts_per_year = covidence[covidence['Author keywords'].str.contains(term.lower())]['Published Year'].value_counts().sort_index()
    term_counts_per_year = term_counts_per_year.reindex(years, fill_value=0)  # Ensure counts for all years, fill missing with 0
    article_counts[term] = term_counts_per_year

print("\nNumber of Articles per Search Term and Year:\n", article_counts)
# Out:
# Number of Articles per Search Term and Year:
#        math anxiety  giftedness  excellence  disabilities  dyscalculia
# 1986             0           0           1             0            0
# 1991             0           1           0             0            0
# 2005             0           1           0             0            0
# 2007             0           0           0             0            1
# 2009             0           0           0             0            4
# 2010             0           2           0             0            1
# 2011             0           2           0             0            1
# 2012             2           2           0             0            1
# 2013             2           2           0             1            2
# 2014             3           4           0             0            0
# 2015             4           1           0             0            2
# 2016             1           2           1             0            1
# 2017             3           1           1             0            0
# 2018             4           1           0             0            3
# 2019             5           0           0             0            0
# 2020             3           1           0             0            2
# 2021             1           2           0             0            1
# 2022             1           0           0             0            0
# 2023             4           1           1             0            1
# 2024             1           0           0             0            0

# %%
# Define the terms to search for
search_terms = ['math anxiety', 'giftedness', 'excellence', 'disabilities', 'dyscalculia']

# Count occurrences of each search term in the 'Author keywords' column
term_counts = {}
for term in search_terms:
    term_counts[term] = covidence['Author keywords'].str.contains(term.lower()).sum()

print("# of each Psychology term")
for term, count in term_counts.items():
    print(f"{term}: {count}")

# Plot the data
plt.figure(figsize=(10, 6))
plt.bar(term_counts.keys(), term_counts.values(), color='skyblue')
plt.title('# of each Psychology term')
plt.xlabel('Psychology Term')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# # of each Psychology term
# math anxiety: 34
# giftedness: 23
# excellence: 4
# disabilities: 1
# dyscalculia: 20
